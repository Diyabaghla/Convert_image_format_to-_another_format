# %% [markdown]
# <a href="https://colab.research.google.com/github/Diyabaghla/Convert_image_format_to-_another_format/blob/main/Convert_image_format_to__another_format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# converting image from one format to another

# %% [markdown]
# Can be done using various libararies such as opencv and pil(pillow)

# %% [markdown]
# Using opencv

# %%
import cv2
#load the image
image=cv2.imread("/content/img.jpeg")
cv2.imwrite('output_image.png',image)
print("image saved in png successfully")
# Out:
# image saved in png successfully

# %%
image1=cv2.imread("/content/output_image.png")
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=201x251>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=201x251>

# %% [markdown]
# Using pillow library

# %%
from PIL import Image
image=Image.open("output_image.png")
image.save("output_image.jpeg","jpeg")
print("image converted successfully")
# Out:
# image converted successfully
